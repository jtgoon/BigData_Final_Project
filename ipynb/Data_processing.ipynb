# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.font_manager as fm
from datetime import datetime

from matplotlib import rc
rc('font',family='AppleGothic')

import matplotlib as mpl
mpl.rcParams['axes.unicode_minus'] = False
from sklearn import linear_model
from scipy import stats
import statsmodels
import statsmodels.api as sm
import statsmodels.formula.api as smf
import glob
import os

import time
import re

# %%
final_data = pd.read_csv('/Users/hanjaemin/Desktop/final_project/BigData_Final_Project/data/movie_data/merge_data.csv')
final_data
# Out:
#              moviename openingdate         sales  attendance  screen  \
# 0                 극한직업   2019.1.23  1.396518e+11  16265618.0  2003.0
# 1                   명량   2014.7.30  1.357484e+11  17613682.0  1587.0
# 2           어벤져스: 엔드게임   2019.4.24  1.221827e+11  13934592.0  2835.0
# 3                  베테랑    2015.8.5  1.051682e+11  13414009.0  1115.0
# 4            신과함께-인과 연    2018.8.1  1.026661e+11  12274996.0  2235.0
# ...                ...         ...           ...         ...     ...
# 1042  더 프린세스 : 도둑맞은 공주   2020.8.12  4.574497e+08     55828.0   423.0
# 1043          프리키 데스데이  2020.11.25  4.512257e+08     51812.0   631.0
# 1044            날씨의 아이  2019.10.30  4.449562e+08     58968.0   194.0
# 1045            눈의 여왕4  2019.12.24  4.446496e+08     67159.0   271.0
# 1046            다크 나이트    2008.8.6  4.071936e+08     51681.0   378.0
#
#       playcount country                       distributor  director  genre  \
# 0      292584.0      한국                         (주)씨제이이엔엠       이병헌    코미디
# 1      188611.0      한국                         (주)씨제이이엔엠       정세교  다큐멘터리
# 2      242001.0      미국                월트디즈니컴퍼니코리아 유한책임회사    안소니 루소     액션
# 3      199231.0      한국                         (주)씨제이이엔엠       류승완     액션
# 4      179981.0      한국                 롯데컬처웍스(주)롯데엔터테인먼트       김용화    판타지
# ...         ...     ...                               ...       ...    ...
# 1042     4192.0   우크라이나                        (주)팝엔터테인먼트    올레 말라므  애니메이션
# 1043    12882.0      미국               유니버설픽쳐스인터내셔널 코리아(유)  크리스토퍼 랜던    코미디
# 1044     5921.0      일본  메가박스중앙(주)플러스엠,(주)미디어캐슬,워터홀컴퍼니(주)   신카이 마코토  애니메이션
# 1045     2239.0     러시아               (주)넥스트엔터테인먼트월드(NEW)    로버트 렌스  애니메이션
# 1046     4445.0      미국        주식회사 해리슨앤컴퍼니,워너브러더스 코리아(주)  크리스토퍼 놀란     액션
#
#                                                   actor  \
# 0                          류승룡(고반장), 이하늬(장형사), 진선규(마형사)
# 1                                     김한민, 오타니 료헤이, 이해영
# 2     로버트 다우니 주니어(토니 스타크 / 아이언맨), 크리스 에반스(스티브 로저스 / ...
# 3                          황정민(서도철), 유아인(조태오), 유해진(최상무)
# 4                            하정우(강림), 주지훈(해원맥), 김향기(덕춘)
# ...                                                 ...
# 1042            사문영(밀라 목소리), 남도형(루슬란 목소리), 서반석(레스터 목소리)
# 1043                                       빈스 본, 캐서린 뉴튼
# 1044                          심규혁(호다카), 김유림(히나), 최한(스가)
# 1045  양정화(눈의 여왕 한국어 목소리), 박지윤(겔다 한국어 목소리), 임채헌(헤럴드 한...
# 1046  크리스찬 베일(브루스 웨인/배트맨), 히스 레저(조커), 아론 에크하트(하비 덴트/...
#
#                      filmrank
# 0                [국내] 15세 관람가
# 1                [국내] 12세 관람가
# 2                [국내] 12세 관람가
# 3                [국내] 15세 관람가
# 4                [국내] 12세 관람가
# ...                       ...
# 1042              [국내] 전체 관람가
# 1043             [국내] 15세 관람가
# 1044             [국내] 15세 관람가
# 1045              [국내] 전체 관람가
# 1046  [국내] 15세 관람가 [해외] PG-13
#
# [1047 rows x 12 columns]

# %%
### 결측행 제거
final_data.dropna(inplace = True)

### 인덱스 재설정
final_data.reset_index(inplace = True, drop = True)

# %%
final_data
# Out:
#              moviename openingdate         sales  attendance  screen  \
# 0                 극한직업   2019.1.23  1.396518e+11  16265618.0  2003.0
# 1                   명량   2014.7.30  1.357484e+11  17613682.0  1587.0
# 2           어벤져스: 엔드게임   2019.4.24  1.221827e+11  13934592.0  2835.0
# 3                  베테랑    2015.8.5  1.051682e+11  13414009.0  1115.0
# 4            신과함께-인과 연    2018.8.1  1.026661e+11  12274996.0  2235.0
# ...                ...         ...           ...         ...     ...
# 1017  더 프린세스 : 도둑맞은 공주   2020.8.12  4.574497e+08     55828.0   423.0
# 1018          프리키 데스데이  2020.11.25  4.512257e+08     51812.0   631.0
# 1019            날씨의 아이  2019.10.30  4.449562e+08     58968.0   194.0
# 1020            눈의 여왕4  2019.12.24  4.446496e+08     67159.0   271.0
# 1021            다크 나이트    2008.8.6  4.071936e+08     51681.0   378.0
#
#       playcount country                       distributor  director  genre  \
# 0      292584.0      한국                         (주)씨제이이엔엠       이병헌    코미디
# 1      188611.0      한국                         (주)씨제이이엔엠       정세교  다큐멘터리
# 2      242001.0      미국                월트디즈니컴퍼니코리아 유한책임회사    안소니 루소     액션
# 3      199231.0      한국                         (주)씨제이이엔엠       류승완     액션
# 4      179981.0      한국                 롯데컬처웍스(주)롯데엔터테인먼트       김용화    판타지
# ...         ...     ...                               ...       ...    ...
# 1017     4192.0   우크라이나                        (주)팝엔터테인먼트    올레 말라므  애니메이션
# 1018    12882.0      미국               유니버설픽쳐스인터내셔널 코리아(유)  크리스토퍼 랜던    코미디
# 1019     5921.0      일본  메가박스중앙(주)플러스엠,(주)미디어캐슬,워터홀컴퍼니(주)   신카이 마코토  애니메이션
# 1020     2239.0     러시아               (주)넥스트엔터테인먼트월드(NEW)    로버트 렌스  애니메이션
# 1021     4445.0      미국        주식회사 해리슨앤컴퍼니,워너브러더스 코리아(주)  크리스토퍼 놀란     액션
#
#                                                   actor  \
# 0                          류승룡(고반장), 이하늬(장형사), 진선규(마형사)
# 1                                     김한민, 오타니 료헤이, 이해영
# 2     로버트 다우니 주니어(토니 스타크 / 아이언맨), 크리스 에반스(스티브 로저스 / ...
# 3                          황정민(서도철), 유아인(조태오), 유해진(최상무)
# 4                            하정우(강림), 주지훈(해원맥), 김향기(덕춘)
# ...                                                 ...
# 1017            사문영(밀라 목소리), 남도형(루슬란 목소리), 서반석(레스터 목소리)
# 1018                                       빈스 본, 캐서린 뉴튼
# 1019                          심규혁(호다카), 김유림(히나), 최한(스가)
# 1020  양정화(눈의 여왕 한국어 목소리), 박지윤(겔다 한국어 목소리), 임채헌(헤럴드 한...
# 1021  크리스찬 베일(브루스 웨인/배트맨), 히스 레저(조커), 아론 에크하트(하비 덴트/...
#
#                      filmrank
# 0                [국내] 15세 관람가
# 1                [국내] 12세 관람가
# 2                [국내] 12세 관람가
# 3                [국내] 15세 관람가
# 4                [국내] 12세 관람가
# ...                       ...
# 1017              [국내] 전체 관람가
# 1018             [국내] 15세 관람가
# 1019             [국내] 15세 관람가
# 1020              [국내] 전체 관람가
# 1021  [국내] 15세 관람가 [해외] PG-13
#
# [1022 rows x 12 columns]

# %%
# openingdate type 변환(object -> DateTime)
final_data['openingdate'] = pd.to_datetime(final_data['openingdate'])
final_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1022 entries, 0 to 1021
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   moviename    1022 non-null   object
#  1   openingdate  1022 non-null   datetime64[ns]
#  2   sales        1022 non-null   float64
#  3   attendance   1022 non-null   float64
#  4   screen       1022 non-null   float64
#  5   playcount    1022 non-null   float64
#  6   country      1022 non-null   object
#  7   distributor  1022 non-null   object
#  8   director     1022 non-null   object
#  9   genre        1022 non-null   object
#  10  actor        1022 non-null   object
#  11  filmrank     1022 non-null   object
# dtypes: datetime64[ns](1), float64(4), object(7)
# memory usage: 95.9+ KB

# %%
### 범주변수 숫자화

## country == 한국 : 0 , country !== 한국 : 1
country_list=[]
for i in range(len(final_data['country'])):
    if final_data['country'][i] == '한국':
        country_list.append(0)
    else:
        country_list.append(1)

final_data['country'] = country_list

# %%
## actor를 이름에서 actor의 수로 변환

final_data['actor'] = final_data.actor.str.count(',') + 1

# %%
## filmrank 

## 전체관람가 : 0, 12세관람가 : 1, 15세관람가 : 2, 청소년관람불가 : 3, 그 외 : 4


## 연령대만 추출 후 숫자형으로 변환

filmrank_num_list=[]

final_data["filmrank"] = [filmrank_num.split()[1] for filmrank_num in final_data['filmrank']]

for i in range(len(final_data['filmrank'])):
    
    if final_data['filmrank'][i] == '전체':
        filmrank_num_list.append(0)
        
    elif final_data['filmrank'][i] == '12세':
        filmrank_num_list.append(1)
    
    elif final_data['filmrank'][i] == '15세':
        filmrank_num_list.append(2)
        
    elif final_data['filmrank'][i] == '청소년':
        filmrank_num_list.append(3)
        
    else:
        filmrank_num_list.append(4)
        

final_data['filmrank'] = filmrank_num_list

# %%
## genre 

## 코미디 : 0, 다큐멘터리 : 1, 액션 : 2, 판타지 : 3, 드라마 : 4, 범죄 : 5, 애니메이션 : 6, SF : 7, 모험 :8,
## 미스터리 : 9, 전쟁 : 10, 멜로/로맨스 : 11, 스릴러, 서스펜스 : 12, 서사 : 13, 공포 : 14, 느와르 : 15, 뮤지컬 : 16,
## 가족 : 17, 그 외 : 18


genre_list=[]

for i in range(len(final_data['genre'])):
    
    if final_data['genre'][i] == '코미디':
        genre_list.append(0)
        
    elif final_data['genre'][i] == '다큐멘터리':
        genre_list.append(1)
    
    elif final_data['genre'][i] == '액션':
        genre_list.append(2)
        
    elif final_data['genre'][i] == '판타지':
        genre_list.append(3)
        
    elif final_data['genre'][i] == '드라마':
        genre_list.append(4)
    
    elif final_data['genre'][i] == '범죄':
        genre_list.append(5)
        
    elif final_data['genre'][i] == '애니메이션':
        genre_list.append(6)
        
    elif final_data['genre'][i] == 'SF':
        genre_list.append(7)
    
    elif final_data['genre'][i] == '모험':
        genre_list.append(8)
        
    elif final_data['genre'][i] == '미스터리':
        genre_list.append(9)      
        
    elif final_data['genre'][i] == '전쟁':
        genre_list.append(10)
    
    elif final_data['genre'][i] == '멜로/로맨스':
        genre_list.append(11)
        
    elif final_data['genre'][i] == '스릴러' or final_data['genre'][i] == '서스펜스' :
        genre_list.append(12)

    elif final_data['genre'][i] == '서사':
        genre_list.append(13)
        
    elif final_data['genre'][i] == '공포':
        genre_list.append(14)
        
    elif final_data['genre'][i] == '느와르':
        genre_list.append(15)
        
    elif final_data['genre'][i] == '뮤지컬':
        genre_list.append(16)
        
    elif final_data['genre'][i] == '가족':
        genre_list.append(17)
    
    else:
        genre_list.append(18)
        

final_data['genre'] = genre_list

# %%
final_data
# Out:
#              moviename openingdate         sales  attendance  screen  \
# 0                 극한직업  2019-01-23  1.396518e+11  16265618.0  2003.0
# 1                   명량  2014-07-30  1.357484e+11  17613682.0  1587.0
# 2           어벤져스: 엔드게임  2019-04-24  1.221827e+11  13934592.0  2835.0
# 3                  베테랑  2015-08-05  1.051682e+11  13414009.0  1115.0
# 4            신과함께-인과 연  2018-08-01  1.026661e+11  12274996.0  2235.0
# ...                ...         ...           ...         ...     ...
# 1017  더 프린세스 : 도둑맞은 공주  2020-08-12  4.574497e+08     55828.0   423.0
# 1018          프리키 데스데이  2020-11-25  4.512257e+08     51812.0   631.0
# 1019            날씨의 아이  2019-10-30  4.449562e+08     58968.0   194.0
# 1020            눈의 여왕4  2019-12-24  4.446496e+08     67159.0   271.0
# 1021            다크 나이트  2008-08-06  4.071936e+08     51681.0   378.0
#
#       playcount  country                       distributor  director  genre  \
# 0      292584.0        0                         (주)씨제이이엔엠       이병헌      0
# 1      188611.0        0                         (주)씨제이이엔엠       정세교      1
# 2      242001.0        1                월트디즈니컴퍼니코리아 유한책임회사    안소니 루소      2
# 3      199231.0        0                         (주)씨제이이엔엠       류승완      2
# 4      179981.0        0                 롯데컬처웍스(주)롯데엔터테인먼트       김용화      3
# ...         ...      ...                               ...       ...    ...
# 1017     4192.0        1                        (주)팝엔터테인먼트    올레 말라므      6
# 1018    12882.0        1               유니버설픽쳐스인터내셔널 코리아(유)  크리스토퍼 랜던      0
# 1019     5921.0        1  메가박스중앙(주)플러스엠,(주)미디어캐슬,워터홀컴퍼니(주)   신카이 마코토      6
# 1020     2239.0        1               (주)넥스트엔터테인먼트월드(NEW)    로버트 렌스      6
# 1021     4445.0        1        주식회사 해리슨앤컴퍼니,워너브러더스 코리아(주)  크리스토퍼 놀란      2
#
#       actor  filmrank
# 0         3         2
# 1         3         1
# 2         3         1
# 3         3         2
# 4         3         1
# ...     ...       ...
# 1017      3         0
# 1018      2         2
# 1019      3         2
# 1020      3         0
# 1021      3         2
#
# [1022 rows x 12 columns]

# %%
final_data.to_csv('/Users/hanjaemin/Desktop/final_project/BigData_Final_Project/data/Preprocessing_movie_data/Data_processing.data.csv',index=False)
final_data.to_excel('/Users/hanjaemin/Desktop/final_project/BigData_Final_Project/data/Preprocessing_movie_data/Data_processing.data.xlsx',index=False)
